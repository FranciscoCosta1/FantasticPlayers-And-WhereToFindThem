# %% [markdown]
# # FIFA 19/20 Players Skills Match

# %% [markdown]
# ## Import libraries

# %%
import time
import pandas as pd

# %% [markdown]
# ## Import CSV files

# %%
FIFA_Player_Stats_filepath = './Input Files/players _ fifa20.csv'
TOP_Players_filepath = './Input Files/Player Match TM FIFA.csv'

df_player_skills = pd.read_csv(FIFA_Player_Stats_filepath)
df_top_players = pd.read_csv(TOP_Players_filepath, delimiter = ',')

# %% [markdown]
# ## Player Skills Dataset

# %%
df_player_skills.head(n = 3)
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# 0        170         72   Argentina         FC Barcelona  ...  68+2  66+2
# 1        187         83    Portugal             Juventus  ...  65+3  61+3
# 2        175         68      Brazil  Paris Saint-Germain  ...  66+3  61+3
#
#     cdm   rdm   rwb    lb   lcb    cb   rcb    rb
# 0  66+2  66+2  68+2  63+2  52+2  52+2  52+2  63+2
# 1  61+3  61+3  65+3  61+3  53+3  53+3  53+3  61+3
# 2  61+3  61+3  66+3  61+3  46+3  46+3  46+3  61+3
#
# [3 rows x 104 columns]

# %% [markdown]
# ## Top Players Dataset

# %%
df_top_players.head(n = 3)
# Out:
#         0                  1   2                3               4       5  \
# 0  462250         João Félix  19  Atlético Madrid  Second Striker  242444
# 1  125781  Antoine Griezmann  28     FC Barcelona  Centre-Forward  194765
# 2   50202        Eden Hazard  28      Real Madrid     Left Winger  183277
#
#               6   7                8  9  10   11  12
# 0    João Félix  19  Atlético Madrid  0   0  0.0   0
# 1  A. Griezmann  28     FC Barcelona  6   6  6.0   0
# 2     E. Hazard  28      Real Madrid  3   3  3.0   0

# %%
df_top_players.columns = ['PlayerID', 'Name', 'Age', 'Team', 'Position', 'PlayerID_FIFA', 'Name_FIFA', 'Age_FIFA', 'Team_FIFA', 'd1', 'd2', 'd3', 'avg_dist']
df_top_players = df_top_players.loc[:,['PlayerID', 'PlayerID_FIFA', 'Position']]
df_top_players.head()
# Out:
#    PlayerID  PlayerID_FIFA        Position
# 0    462250         242444  Second Striker
# 1    125781         194765  Centre-Forward
# 2     50202         183277     Left Winger
# 3    177907         203263     Centre-Back
# 4    326031         235243     Centre-Back

# %% [markdown]
# ## Display Transfer Markt position names

# %%
df_top_players['Position'].value_counts()
# Out:
# Centre-Forward        4
# Centre-Back           4
# Central Midfield      4
# Left Winger           2
# Right-Back            2
# Second Striker        1
# Right Winger          1
# Left-Back             1
# Defensive Midfield    1
# Name: Position, dtype: int64

# %% [markdown]
# ## Display the most relevant FIFA position name (first one)

# %%
df_player_skills['player_positions'] = df_player_skills['player_positions'].str.split(',', expand = True)[0]

# %%
df_player_skills['player_positions'].str.split(',', expand = True)[0].value_counts()
# Out:
# CB     3162
# ST     2582
# CM     2193
# GK     2036
# CDM    1424
# RB     1314
# LB     1303
# CAM    1146
# RM     1050
# LM     1049
# LW      378
# RW      369
# CF      113
# LWB      90
# RWB      69
# Name: 0, dtype: int64

# %% [markdown]
# ## Mapping dictionary for position names

# %%
positions = {
    'Centre-Back': 'CB',
    'Centre-Forward': 'CF',
    'Central Midfield': 'CM',
    'Left Winger': 'LW',
    'Right-Back': 'RB',
    'Right Winger': 'RW',
    'Second Striker': 'ST',
    'Defensive Midfield': 'CDM',
    'Left-Back': 'LB'
            }

# %% [markdown]
# ## Select the relevant columns for skill comparison

# %%
df_player_skills = df_player_skills.loc[:,['sofifa_id', 'player_positions', 'pace', 'shooting', 'passing', 'dribbling', 'defending', 'physic']]
df_player_skills = df_player_skills.dropna()
df_player_skills.head()
# Out:
#    sofifa_id player_positions  pace  shooting  passing  dribbling  defending  \
# 0     158023               RW  87.0      92.0     92.0       96.0       39.0
# 1      20801               ST  90.0      93.0     82.0       89.0       35.0
# 2     190871               LW  91.0      85.0     87.0       95.0       32.0
# 4     183277               LW  91.0      83.0     86.0       94.0       35.0
# 5     192985              CAM  76.0      86.0     92.0       86.0       61.0
#
#    physic
# 0    66.0
# 1    78.0
# 2    58.0
# 4    66.0
# 5    78.0

# %% [markdown]
# ## Merge the two datasets (TOP Players & Player Skills)

# %%
df_top_players = pd.merge(df_top_players, df_player_skills, how='left', left_on=['PlayerID_FIFA'], right_on=['sofifa_id'])
df_top_players
# Out:
#     PlayerID  PlayerID_FIFA            Position  sofifa_id player_positions  \
# 0     462250         242444      Second Striker     242444               CF
# 1     125781         194765      Centre-Forward     194765               CF
# 2      50202         183277         Left Winger     183277               LW
# 3     177907         203263         Centre-Back     203263               CB
# 4     326031         235243         Centre-Back     235243               CB
# 5     343052         226110        Right Winger     226110               RM
# 6     281963         220814         Centre-Back     220814               CB
# 7     326330         228702    Central Midfield     228702               CM
# 8     357565         231866  Defensive Midfield     231866              CDM
# 9     182712         210514          Right-Back     210514               RB
# 10     96341         192505      Centre-Forward     192505               ST
# 11    450936         235569    Central Midfield     235569               CM
# 12    257462         232432      Centre-Forward     232432               ST
# 13    477758         229880          Right-Back     229880               RB
# 14    401530         240130         Centre-Back     240130               CB
# 15    291417         228618           Left-Back     228618               LB
# 16     51471         207410    Central Midfield     207410               CM
# 17    412363         243812         Left Winger     243812               LW
# 18    249565         216393    Central Midfield     216393               CM
# 19    333241         223334      Centre-Forward     223334               ST
#
#     pace  shooting  passing  dribbling  defending  physic
# 0   82.0      80.0     74.0       81.0       40.0    70.0
# 1   81.0      86.0     84.0       89.0       57.0    72.0
# 2   91.0      83.0     86.0       94.0       35.0    66.0
# 3   50.0      53.0     64.0       69.0       81.0    84.0
# 4   67.0      58.0     66.0       68.0       83.0    84.0
# 5   91.0      81.0     75.0       85.0       33.0    67.0
# 6   81.0      54.0     70.0       71.0       83.0    82.0
# 7   79.0      64.0     84.0       87.0       76.0    76.0
# 8   67.0      68.0     77.0       77.0       82.0    80.0
# 9   90.0      65.0     80.0       84.0       78.0    71.0
# 10  75.0      82.0     73.0       72.0       35.0    84.0
# 11  80.0      65.0     78.0       87.0       70.0    78.0
# 12  77.0      82.0     68.0       81.0       29.0    74.0
# 13  87.0      50.0     63.0       78.0       80.0    72.0
# 14  79.0      50.0     66.0       71.0       81.0    81.0
# 15  89.0      64.0     73.0       79.0       75.0    81.0
# 16  76.0      68.0     81.0       86.0       67.0    70.0
# 17  85.0      72.0     65.0       80.0       29.0    57.0
# 18  63.0      78.0     82.0       78.0       68.0    67.0
# 19  78.0      75.0     60.0       76.0       43.0    81.0

# %% [markdown]
# ## Skills comparison code

# %%
match_list = []
start_time = time.time()

for top_player in list(df_top_players.itertuples(index = False, name = None)):
    
    PlayerID = top_player[0]
    PlayerID_FIFA = top_player[1]
    PlayerPosition = top_player[2]
    PlayerSkills = top_player[-6:]
    max_skills_dif = 100
    
    for matched_player in list(df_player_skills.loc[df_player_skills['player_positions'] == positions[PlayerPosition]].itertuples(index = False, name = None)):
        
        MatchedPlayerID_FIFA = matched_player[0]
        MatchedPlayerSkills = matched_player[-6:]
        
        if PlayerID_FIFA == MatchedPlayerID_FIFA: 
            continue
            
        else:
            
            skills_dif = [(a - b)**2 for a, b in zip(PlayerSkills, MatchedPlayerSkills)]
            avg_skills_dif = sum(skills_dif)**(1/2)
            
            match_list.append([PlayerID, PlayerID_FIFA, MatchedPlayerID_FIFA, avg_skills_dif])

df = pd.DataFrame(match_list)    
print('Process completed in:', time.time() - start_time, 'seconds.')
# Out:
# Process completed in: 0.2330160140991211 seconds.

# %% [markdown]
# ## Set column names

# %%
df.columns = ['PlayerID', 'PlayerID_FIFA', 'MatchedPlayerID_FIFA', 'Distance']

# %% [markdown]
# ## Collect the best 10 player matches (minimum distance)

# %%
df = df.set_index('MatchedPlayerID_FIFA').groupby(['PlayerID', 'PlayerID_FIFA'])['Distance'].nsmallest(10).reset_index()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
# PlayerID                200 non-null int64
# PlayerID_FIFA           200 non-null int64
# MatchedPlayerID_FIFA    200 non-null int64
# Distance                200 non-null float64
# dtypes: float64(1), int64(3)
# memory usage: 6.3 KB

# %%
df.head()
# Out:
#    PlayerID  PlayerID_FIFA  MatchedPlayerID_FIFA   Distance
# 0     50202         183277                190871   8.888194
# 1     50202         183277                222492  12.569805
# 2     50202         183277                208808  14.560220
# 3     50202         183277                208722  16.124515
# 4     50202         183277                229906  16.278821

# %% [markdown]
# ## Export results to csv file

# %%
df.to_csv('./Output Files/Player Skills Match.csv', index = False)
